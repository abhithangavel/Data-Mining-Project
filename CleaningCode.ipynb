# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import statistics as stats
# %matplotlib inline

# %%
groc = pd.read_csv("groceriesFull.csv")

# %%
groc.head()
# Out:
#    Items            Item 1               Item 2          Item 3  \
# 0      4      citrus fruit  semi-finished bread       margarine
# 1      3    tropical fruit               yogurt          coffee
# 2      1        whole milk                  NaN             NaN
# 3      4         pip fruit               yogurt    cream cheese
# 4      4  other vegetables           whole milk  condensed milk
#
#                      Item 4 Item 5 Item 6 Item 7 Item 8 Item 9  ... Item 23  \
# 0               ready soups    NaN    NaN    NaN    NaN    NaN  ...     NaN
# 1                       NaN    NaN    NaN    NaN    NaN    NaN  ...     NaN
# 2                       NaN    NaN    NaN    NaN    NaN    NaN  ...     NaN
# 3              meat spreads    NaN    NaN    NaN    NaN    NaN  ...     NaN
# 4  long life bakery product    NaN    NaN    NaN    NaN    NaN  ...     NaN
#
#   Item 24 Item 25 Item 26 Item 27 Item 28 Item 29 Item 30 Item 31 Item 32
# ...

# %%
columns = groc.columns.tolist()
print(columns)
# Out:
# ['Items', 'Item 1', 'Item 2', 'Item 3', 'Item 4', 'Item 5', 'Item 6', 'Item 7', 'Item 8', 'Item 9', 'Item 10', 'Item 11', 'Item 12', 'Item 13', 'Item 14', 'Item 15', 'Item 16', 'Item 17', 'Item 18', 'Item 19', 'Item 20', 'Item 21', 'Item 22', 'Item 23', 'Item 24', 'Item 25', 'Item 26', 'Item 27', 'Item 28', 'Item 29', 'Item 30', 'Item 31', 'Item 32']

# %%
itm_mean = groc['Items'].mean()
print(itm_mean)
# Out:
# 4.409456024402644

# %%
all_itm = pd.Series(groc.values.ravel('F'))
itm_counts = all_itm.value_counts()

# %%
sorted_count = itm_counts.sort_values(ascending = False)

# %%
#plot
plt.figure(figsize=(10, 6))
sorted_count.plot(kind='bar', color='skyblue', width=3)
plt.title('Common Grocery Items')
plt.xlabel('Grocery Item')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 8))
bars = sorted_count.plot(kind='barh', color='skyblue', width=0.5)

plt.title('Common Grocery Items')
plt.xlabel('Count')
plt.ylabel('Grocery Item')
plt.tight_layout()

plt.show()

# %%
from wordcloud import WordCloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(all_itm)

plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 2
#       1 from wordcloud import WordCloud
# ----> 2 wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(all_itm)
#       4 plt.figure(figsize=(10, 6))
#       5 plt.imshow(wordcloud, interpolation='bilinear')
#
# File ~\anaconda3\lib\site-packages\wordcloud\wordcloud.py:408, in WordCloud.generate_from_frequencies(self, frequencies, max_font_size)
#     392 """Create a word_cloud from words and frequencies.
#     393
#     394 Parameters
#    (...)
#     405
#     406 """
#     407 # make sure frequencies are sorted and normalized
# --> 408 frequencies = sorted(frequencies.items(), key=itemgetter(1), reverse=True)
#     409 if len(frequencies) <= 0:
#     410     raise ValueError("We need at least 1 word to plot a word cloud, "
# ...
